# %% [markdown]
# <a href="https://colab.research.google.com/github/svwn390-glitch/cs1q4_practicaltest/blob/main/cs1q4_practicaltest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter student name: ")
amt_of_scores = int(input("How many scores will you input:"))

scores = []
for i in range(amt_of_scores):
    score = int(input(f"Enter score {i+1}: "))
    scores.append(score)

if scores:
    average_score = sum(scores) / len(scores)
    print(f"\nStudent: {name}")
    print(f"Average Score: {average_score:.2f}")
    if average_score >= 75:
        print("Result: Passed")
    else:
        print("Result: Failed")
else:
    print("No scores were entered.")
